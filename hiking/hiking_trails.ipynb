# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
import requests
URL = "https://www.wikiloc.com/trails/hiking/switzerland/"
r = requests.get(URL)
print(r.content)
# Out:
# b'<html>\n<head><title>503 Service Temporarily Unavailable</title></head>\n<body>\n<center><h1>503 Service Temporarily Unavailable</h1></center>\n<hr><center>nginx</center>\n<script defer src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" data-cf-beacon=\'{"rayId":"73582fe04fd4b8ba","token":"a711f439afb74b99ad527f2d96a6c2a2","version":"2022.6.0","si":100}\' crossorigin="anonymous"></script>\n</body>\n</html>\n'

# %%
import cloudscraper


url = "https://www.wikiloc.com/trails/hiking/switzerland/"


scraper = cloudscraper.create_scraper()
q1 = scraper.get(url)
soup = BeautifulSoup(q1.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: http://ogp.me/ns#">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="Wikiloc" name="author"/>
# <link href="https://sc.wklcdn.com" rel="dns-prefetch"/>
# <link href="https://s0.wklcdn.com" rel="dns-prefetch"/>
# <link href="https://s1.wklcdn.com" rel="dns-prefetch"/>
# <link href="https://s2.wklcdn.com" rel="dns-prefetch"/>
# <link href="https://s3.wklcdn.com" rel="dns-prefetch"/>
# <meta content="The Best Hiking Trails in Switzerland | Wikiloc" name="title">
# <meta content="Find the best Hiking trails in Switzerland. Discover the most beautiful places, download GPS tracks and follow the top routes on a map. Record your own trail from the Wikiloc app, upload it and share it with the community." name="description">
# <meta content="summary" name="twitter:card"/>
# <meta content="@wikiloc" name="twitter:site">
# <meta content="The Best Hiking Trails in Switzerland | Wikiloc" name="twitter:title">
# <meta content="Find the best Hiking trails in Switzerland. Discover the most beautiful places, download GPS tracks and follow the top routes on a map. Record your own trail from the Wikiloc app, upload it and share it with the community." name="twitter:description">
# <meta content="The Best Hiking Trails in Switzerland | Wikiloc" property="og:title">
# <meta content="Wikiloc | Trails of the World" property="og:site_name"/>
# <meta content="Find the best Hiking trails in Switzerland. Discover the most beautiful places, download GPS tracks and follow the top routes on a map. Record your own trail from the Wikiloc app, upload it and share it with the community." property="og:description"/>
# <meta content="https://sc.wklcdn.com/wikiloc/images/wikiloc-logo-facebook.png" property="og:image"/>
# <title>The Best Hiking Trails in Switzerland | Wikiloc</title>
# <link href="https://sc.wklcdn.com/favicon.ico?v=3.0" rel="shortcut icon" type="image/ico"/>
# <link href="https://sc.wklcdn.com/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.2/css/bootstrap.min.css" rel="stylesheet"/>
# <link as="font" crossorigin="" href="https://sc.wklcdn.com/wikiloc/assets/styles/fonts/font/wikiloc-font.woff2?35475463" rel="preload" type="font/woff2"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/wikiloc.min.f844bbd3.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/wikiloc-v2.min.4e9634de.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/fonts/css/wikiloc-font.min.7a3ba9d0.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,500,700&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Montserrat:400,600,800&amp;display=swap" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/search-box.min.a325253b.css" rel="stylesheet">
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/explore.min.b5d40919.css" rel="stylesheet">
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/header-user.min.73311101.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/language-selector.min.80932ac1.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/landings.min.5812c6bd.css" rel="stylesheet" type="text/css">
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/pictograms.min.d167e6e4.css?v=1.1.16" rel="stylesheet" type="text/css"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/stars.min.76e88f7e.css" media="none" onload="if(media!='all')media='all'" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/pagination.min.77d76d81.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/trail-card-with-description-reviews.min.c635c292.css" rel="stylesheet"/>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/adpremium.min.31d7b38f.css" rel="stylesheet"/>
# <link href="https://www.wikiloc.com/trails/hiking/switzerland" rel="canonical"/>
# <link href="https://www.wikiloc.com/trails/hiking/switzerland" hreflang="en" rel="alternate">
# <link href="https://es.wikiloc.com/rutas/senderismo/suiza" hreflang="es" rel="alternate">
# <link href="https://ca.wikiloc.com/rutes/senderisme/suissa" hreflang="ca" rel="alternate">
# <link href="https://gl.wikiloc.com/rutas/sendeirismo/suiza" hreflang="gl" rel="alternate">
# <link href="https://eu.wikiloc.com/ibilbideak/senderismo/suitza" hreflang="eu" rel="alternate"/>
# <link href="https://fr.wikiloc.com/itineraires/randonnee/suisse" hreflang="fr" rel="alternate"/>
# <link href="https://it.wikiloc.com/percorsi/escursionismo/svizzera" hreflang="it" rel="alternate"/>
# <link href="https://sv.wikiloc.com/spar/vandra/schweiz" hreflang="sv" rel="alternate"/>
# <link href="https://nl.wikiloc.com/routes/wandelen/zwitserland" hreflang="nl" rel="alternate"/>
# <link href="https://de.wikiloc.com/routen/wandern/schweiz" hreflang="de" rel="alternate"/>
# <link href="https://uk.wikiloc.com/marshruty/pokhid/switzerland" hreflang="uk" rel="alternate"/>
# <link href="https://ru.wikiloc.com/marshruty/pokhod/switzerland" hreflang="ru" rel="alternate"/>
# <link href="https://el.wikiloc.com/diadromes/oreibasia/switzerland" hreflang="el" rel="alternate"/>
# <link href="https://sr.wikiloc.com/rute/pjesacenje-po-planinama/switzerland" hreflang="sr" rel="alternate"/>
# <link href="https://hu.wikiloc.com/nyomvonalak/turazas/switzerland" hreflang="hu" rel="alternate"/>
# <link href="https://pl.wikiloc.com/szlaki/wycieczki-piesze/switzerland" hreflang="pl" rel="alternate"/>
# <link href="https://pt.wikiloc.com/trilhas/trekking/suica" hreflang="pt" rel="alternate"/>
# <link href="https://tr.wikiloc.com/rotalari/gezi-yuruyus/isvicre" hreflang="tr" rel="alternate"/>
# <link href="https://is.wikiloc.com/slodir/fjallaferd/switzerland" hreflang="is" rel="alternate"/>
# <link href="https://da.wikiloc.com/spor/vandring/switzerland" hreflang="da" rel="alternate"/>
# <link href="https://zh.wikiloc.com/hangxian/jian-xing/switzerland" hreflang="zh" rel="alternate"/>
# <link href="https://fi.wikiloc.com/reitit/vaellus/switzerland" hreflang="fi" rel="alternate"/>
# <link href="https://ko.wikiloc.com/teureil/haiking/switzerland" hreflang="ko" rel="alternate"/>
# <link href="https://nb.wikiloc.com/loeyper/fottur/switzerland" hreflang="nb" rel="alternate"/>
# <link href="https://www.wikiloc.com/trails/hiking/switzerland" hreflang="x-default" rel="alternate"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-349413-1"></script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/apply-sid-rules.min.61293dcd.js"></script>
# <script>
#   CookiePolicy.applyCookieAnalisis();
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-349413-1', {
#     'custom_map': {
#       'dimension1': 'dimension_activity',
#       'dimension2': 'dimension_country',
#       'dimension3': 'dimension_region',
#       'dimension4': 'dimension_place',
#       'dimension5': 'dimension_insession',
#       'dimension6': 'dimension_lp_country',
#       'dimension7': 'dimension_lp_region',
#       'dimension8': 'dimension_lp_place',
#       'dimension9': 'dimension_lp_activity',
#     },
#   });
#
#   gtag(
#       'event',
#       'any_event_name',
#       {
#         'dimension_lp_country': 'CH',
#         'dimension_lp_region': '',
#         'dimension_lp_place': '',
#         'dimension_lp_activity': '1'
#       }
#   );
#   </script>
# <script type="application/ld+json">
# 		{
# 			"@context": "http://schema.org",
# 			"@type": "CreativeWorkSeries",
# 			"name": "The Best Hiking Trails in Switzerland | Wikiloc",
# 			"description": "Find the best Hiking trails in Switzerland. Discover the most beautiful places, download GPS tracks and follow the top routes on a map. Record your own trail from the Wikiloc app, upload it and share it with the community.",
# 			"image": "https://s1.wklcdn.com/image_107/3219139/28737190/18369943.jpg",
# 			"aggregateRating": {
# 				"@type": "AggregateRating",
# 				"ratingValue": 4.6,
# 				"reviewCount": 1730
# 			}
# 		}
# 	</script>
# </link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></head>
# <body>
# <header>
# <div id="vue-language-selector"></div>
# <nav class="header" role="navigation">
# <div class="header__content">
# <a class="header__brand" href="https://www.wikiloc.com">
# <img alt="Wikiloc - Trails of the World" class="header__logo-big" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/logo/wikiloc_logo.svg?v=3.0"/>
# </a>
# <div class="header__search">
# <div class="component-search-box"></div>
# </div>
# <div class="header__explore"><span class="header__explore-or">or </span><div class="component-explore"></div>
# </div>
# <div class="header__create">
# <a class="header__create-button-big" href="https://www.wikiloc.com/wikiloc/create.do">
# <span class="header__create-button-big-icon-circle"></span>
# <span class="header__create-button-big-text">
#                             Upload trails</span>
# </a>
# <a class="header__create-button-small" href="https://www.wikiloc.com/wikiloc/create.do">
# <span class="header__create-button-small-icon-circle"></span>
# <span class="header__create-button-mini-icon-circle"></span>
# </a>
# </div>
# <div class="header__user">
# <div class="header__user-guest">
# <a class="btn btn-link header__login" href="https://www.wikiloc.com/wikiloc/start.do?NEXTHOP=aHR0cHM6Ly93d3cud2lraWxvYy5jb20vdHJhaWxzL2hpa2luZy9zd2l0emVybGFuZA==">
#                                     Log in</a>
# <div class="header__signup">
# <a class="header__signup-btn btn btn-warning" href="https://www.wikiloc.com/wikiloc/signingup.do">
#                                         Sign up</a>
# <a class="header__signup-btn-small btn btn-warning" href="https://www.wikiloc.com/wikiloc/signingup.do">
# <i class="icon icon-user"></i>
#                                         Sign up</a>
# </div>
# </div> </div> </div> </nav> </header>
# <script>
# 	var translations = {"txtExploreIreland":"Ireland","txtExploreAustralia":"Australia","txtExploreTurkey":"Turkey","txtWorldmap":"World Map","txtNotificationConfirm":"Confirm","txtNotificationIgnore":"Ignore","txtTrails":"Your trails","txtSearchByText":"Trails with the text: '<span>{0}<\/span>'","txtUrlExploreMoreCountries":"trails","txtSignOut":"Sign out","txtExploreUnitedStates":"United States","txtExploreNepal":"Nepal","txtExplore":"Explore","txtGetPremium":"Upgrade to Premium","txtExploreIceland":"Iceland","txtExploreSpain":"Spain","txtExploreJapan":"Japan","txtNotificationTitle":"Pending requests from your trail buddies","txtSettings":"Settings","txtExploreChile":"Chile","txtExplorePeru":"Peru","txtChangeLanguage":"Change language","txtClose":"Close","txtProducts":"Your products","txtExploreNorway":"Norway","txtExploreMoreCountries":"More countries","txtNearbyTrails":"Nearby trails","txtSearchPlaceholder":"Search for trails","txtExploreVietnam":"Vietnam","txtExplorePhilippines":"Philippines","txtExploreTrailsIn":"Trails in <span>{0}<\/span>","txtContinue":"Continue","txtExploreNewZealand":"New Zealand","txtRecentSearches":"Recent searches","txtSearchExamples":"Try: Yosemite, Appalachian Trail","txtExploreGermany":"Germany","txtProfile":"Your profile","txtExploreItaly":"Italy","txtSearchByUser":"Members with username: '<span>{0}<\/span>'","txtExploreMorocco":"Morocco","txtWithText":"With the text '<strong>{0}<\/strong>'","txtOtherPlaces":"Others","txtExploreFrance":"France","txtExploreTitle":"A World to Explore"};
# 	// Used in common-v2 vueHeaderUser initialization
# 	var INJECT_HEADER = {
# 		userId: "",
# 		username: "",
# 		photo: "",
# 		hasPremium: false,
# 		hasProducts: false,
# 		hasBigAvatar: false,	// only set true at home.jsp
# 		notifications: {},
# 		i18n: translations,
#         languages: [{"changeLanguage":"Canvia idioma","continue":"Continua","subdomain":"ca","text":"Català"}, {"changeLanguage":"Skift sprog","continue":"Fortsæt","subdomain":"da","text":"Dansk"}, {"changeLanguage":"Sprache ändern","continue":"Fortsetzen","subdomain":"de","text":"Deutsch"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"en","text":"English"}, {"changeLanguage":"Cambia idioma","continue":"Continúa","subdomain":"es","text":"Español"}, {"changeLanguage":"Hizkuntza aldatu","continue":"Jarraitu","subdomain":"eu","text":"Euskara"}, {"changeLanguage":"Changer de langue","continue":"Continuer","subdomain":"fr","text":"Français"}, {"changeLanguage":"Cambiar idioma","continue":"Continuar","subdomain":"gl","text":"Galego"}, {"changeLanguage":"Skipta um tungumál","continue":"Halda áfram","subdomain":"is","text":"Íslenska"}, {"changeLanguage":"Cambia lingua","continue":"Continua","subdomain":"it","text":"Italiano"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"hu","text":"Magyar"}, {"changeLanguage":"Taal wijzigen","continue":"Doorgaan","subdomain":"nl","text":"Nederlands"}, {"changeLanguage":"Endre språk","continue":"Fortsett","subdomain":"nb","text":"Norsk"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"pl","text":"Polski"}, {"changeLanguage":"Mudar idioma","continue":"Continuar","subdomain":"pt","text":"Português"}, {"changeLanguage":"Vaihda kieltä","continue":"Jatka","subdomain":"fi","text":"Suomi"}, {"changeLanguage":"Ändra språk","continue":"Fortsätt","subdomain":"sv","text":"Svenska"}, {"changeLanguage":"Dili değiştir","continue":"Devam et","subdomain":"tr","text":"Türkçe"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"el","text":"Ελληνικά"}, {"changeLanguage":"Смена языка","continue":"Продолжить","subdomain":"ru","text":"Русский"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"sr","text":"Српски"}, {"changeLanguage":"Change language","continue":"Continue","subdomain":"uk","text":"Українська"}, {"changeLanguage":"改变语言","continue":"继续","subdomain":"zh","text":"中文"}, {"changeLanguage":"언어 변경","continue":"계속하기","subdomain":"ko","text":"한국어"}]
# 	};
# </script>
# <!--[if lt IE 10]>
# <p class="browsehappy alert alert-warning text-center">Your browser version is <strong>outdated</strong>. Update your browser to view this website correctly. <a href="http://browsehappy.com/?locale=en" class="alert-link">Update my browser now</a>.</p>
# <![endif]--><div class="landing-page__gradient"></div>
# <main class="container landing-page" id="page">
# <div class="row lang-anchor">
# <div class="col-xs-12 lading__head">
# <nav aria-label="Breadcrumb" class="breadcrumbs">
# <a class="breadcrumb--link" href="https://www.wikiloc.com/trails">Explore</a>
#
# 							→ <a class="breadcrumb--link" href="https://www.wikiloc.com/trails/hiking">Hiking trails</a>
#
# 									→ <span class="current"><strong>Switzerland</strong></span>
# </nav>
# <div class="heading">
# <img alt="Hiking" class="heading__icon" height="30" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg">
# <h1>The Best Hiking Trails in Switzerland</h1>
# </img></div>
# <div class="subtitle landing__separador" role="note">
# <h3 class="subtitle__text">80,400 trails</h3>
# <div class="subtitle__dot-separator"></div>
# <div class="rating-container">
# <span class="rating star4_5" title="Rating: 4.6"></span>
# <span aria-label="Reviews" class="rating__count subtitle__text">(1730)</span>
# </div>
# </div>
# </div>
# </div>
# <div class="row" id="content"> <section aria-label="Photos" class="hero col-xs-12">
# <span aria-label="Photo of Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc" class="hero__first launch-viewer" data-href="/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190/photo-18369943">
# <picture>
# <source media="(max-width: 600px)" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.400x300.jpg"/>
# <img alt="Photo of Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc" class="hero__img img-responsive" height="525" src="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.700x525.jpg" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.400x300.jpg 400w, https://s1.wklcdn.com/image_107/3219139/28737190/18369943.700x525.jpg 700w" width="700"/>
# </picture>
# </span>
# <span aria-label="Photo of Tour de Grand Dixence, Valais, SUISSE" class="hero__second launch-viewer" data-href="/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989/photo-17943042">
# <picture>
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.400x300.jpg"/>
# <img alt="Photo of Tour de Grand Dixence, Valais, SUISSE" class="hero__img img-responsive" height="525" src="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.700x525.jpg" srcset="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.400x300.jpg 400w, https://s0.wklcdn.com/image_100/3016011/28086990/17943042.700x525.jpg 700w" width="700"/>
# </picture>
# </span>
# <span aria-label="Photo of Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt" class="hero__third launch-viewer" data-href="/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236/photo-25744100">
# <picture>
# <source media="(max-width: 600px)" srcset="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.400x300.jpg"/>
# <img alt="Photo of Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt" class="hero__img img-responsive" height="525" src="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.700x525.jpg" srcset="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.400x300.jpg 400w, https://s2.wklcdn.com/image_90/2701283/39699236/25744100.700x525.jpg 700w" width="700"/>
# </picture>
# </span>
# </section>
# <!-- /tools -->
# <div class="tools col-xs-12 display">
# <a class="wlbutton wlbutton--md wlbutton--pri-green landing__go-map" href="/wikiloc/map.do?sw=-89.999%2C-179.999&amp;ne=89.999%2C179.999&amp;fitMapToTrails=1&amp;act=1&amp;c=CH" onclick="gtag('event', 'landing_activities', {event_category: 'show_map'});" rel="nofollow">
# <img alt="Show map" aria-hidden="true" class="map__icon" height="16" src="https://sc.wklcdn.com/wikiloc/images/explore-map-white.svg" width="15"/>
# 					Show map</a>
# </div>
# <!-- /tools -->
# <div class="col-xs-12 col-sm-8 col-sm-push-4" id="trails" style="padding: 0 0 2em;"> <ul class="trail-list" id="v-trail-list">
# <li class="trail-list__item">
# <article @click="goToUrl('/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190')" class="trail">
# <div class="trail__header">
# <h2 class="trail__title">
# <a href="/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190" title="Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc trail - Le Pissot, Canton de Fribourg (Switzerland)">
# 												Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc</a>
# </h2>
# <div class="trail__subtitle">
# <small @click.stop="saveTrailToList(28737190)" class="trail__fav" role="button">
# <div :class="false ? 'icon-save-to-list--saved' : 'icon-save-to-list--empty'" class="trail__savetolist-img icon-save-to-list" ref="fav-icon-28737190">
# </div>
# <span class="trail__savetolist-text">
# 													Save to a List</span>
# </small>
# <div class="trail__activity">
# <img alt="Activity" aria-hidden="true" class="trail__activity__icon" height="25" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg"/>
# <span>Hiking</span>
# </div>
# </div>
# </div>
# <div class="trail__near">near Le Pissot, Canton de Fribourg (Switzerland)</div>
# <div class="trail__detail">
# <div aria-label="Author" class="trail__detail__author">
# <a href="https://www.wikiloc.com/wikiloc/user.do?id=3219139" title="Ruben.hera">
# <img alt="Author" class="trail__detail__author__img" height="45" loading="lazy" src="https://s1.wklcdn.com/image_107/3219139/photo_tn.jpg?1531771060527" width="45"/>
# </a>
# <div class="flex--vertical">
# <a class="trail__detail__author__name" href="https://www.wikiloc.com/wikiloc/user.do?id=3219139">
# 														Ruben.hera</a>
# <div class="trail__detail__author__companions">
# <small class="trail__detail__author__companions__with">with</small>
# <a href="/wikiloc/user.do?id=4006175" style="z-index: 1" title="aidacierco">
# <img alt="aidacierco" height="28" loading="lazy" src="https://s2.wklcdn.com/image_133/4006175/photo_tn.jpg?1527637003018" width="28"/>
# </a>
# </div>
# </div>
# </div>
# <dl class="trail__detail__stats">
# <div>
# <dt class="trail__detail__stats__name">Distance</dt>
# <dd class="trail__detail__stats__value">9.80mi</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">Elevation +</dt>
# <dd class="trail__detail__stats__value">2776f</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">TrailRank</dt>
# <dd class="trail__detail__stats__value">
# 													83<span class="trail__rating__separator">|</span>
# <img alt="Rating" class="trail__rating__star" height="18" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/search/star.svg" width="18"/>
# 														5.0</dd>
# </div>
# </dl>
# </div>
# <div class="trail__images trail__images--grid-3">
# <picture @click.stop="goToUrl('/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190/photo-18369943')" class="trail__images--grid-3__0">
# <source media="(max-width: 600px)" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.400x300.jpg"/>
# <img alt="Photo of Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc" class="img-responsive" height="525" loading="lazy" src="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.700x525.jpg" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369943.400x300.jpg 400w, https://s1.wklcdn.com/image_107/3219139/28737190/18369943.700x525.jpg 700w" width="700">
# </img></picture>
# <picture @click.stop="goToUrl('/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190/photo-18369949')" class="trail__images--grid-3__1">
# <source media="(max-width: 600px)" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369949.400x300.jpg"/>
# <img alt="Photo of Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc" class="img-responsive" height="525" loading="lazy" src="https://s1.wklcdn.com/image_107/3219139/28737190/18369949.700x525.jpg" srcset="https://s1.wklcdn.com/image_107/3219139/28737190/18369949.400x300.jpg 400w, https://s1.wklcdn.com/image_107/3219139/28737190/18369949.700x525.jpg 700w" width="700"/>
# </picture>
# <picture @click.stop="goToUrl('/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190/photo-18356441')" class="trail__images--grid-3__2">
# <source media="(max-width: 600px)" srcset="https://s2.wklcdn.com/image_107/3219139/28737191/18356441.400x300.jpg"/>
# <img alt="Photo of Broc - Gorges de la Jogne - Tour du lac de Montsalvens - Broc" class="img-responsive" height="525" loading="lazy" src="https://s2.wklcdn.com/image_107/3219139/28737191/18356441.700x525.jpg" srcset="https://s2.wklcdn.com/image_107/3219139/28737191/18356441.400x300.jpg 400w, https://s2.wklcdn.com/image_107/3219139/28737191/18356441.700x525.jpg 700w" width="700"/>
# </picture>
# </div>
# <p class="trail__description">
# 												English (Castellano debajo):
#
# Easy hike with lots of stairs through the gorge and around a very cool lake.
# We started in the parking lot right after Broc. It's a free parking but be careful as there is not a huge sign...</p>
# <div class="trail__review__container">
# <figure class="trail__review trail__review__0">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Refrescante paseo para hacer también en verano a la sombra de las hayas que crecen en las gargantas.
#
# Nos dejamos pendie...</q>
# <figcaption class="trail__review__author">Daniel Rubio</figcaption>
# </figure>
# <figure class="trail__review trail__review__1">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Muchas gracias por compartir. He realizado hoy esta ruta y ha sido muy agradable, sobre todo la parte de la garganta. Un...</q>
# <figcaption class="trail__review__author">nichtz5</figcaption>
# </figure>
# <figure class="trail__review trail__review__2">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">what a beautiful route,it is the best trail with wonderful photo</q>
# <figcaption class="trail__review__author">mehdi.tabibvand</figcaption>
# </figure>
# </div>
# <a class="trail__viewtrail" href="/hiking-trails/broc-gorges-de-la-jogne-tour-du-lac-de-montsalvens-broc-28737190">
# 										View trail<img alt="View trail" aria-hidden="true" class="trail__viewtrail__arrow" height="14" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/arrow-right-with-line.svg" width="16"/>
# </a>
# </article>
# </li><li class="trail-list__item">
# <article @click="goToUrl('/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989')" class="trail">
# <div class="trail__header">
# <h2 class="trail__title">
# <a href="/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989" title="Tour de Grand Dixence, Valais, SUISSE trail - Ausserholligen, Canton du Valais (Switzerland)">
# 												Tour de Grand Dixence, Valais, SUISSE</a>
# </h2>
# <div class="trail__subtitle">
# <small @click.stop="saveTrailToList(28086989)" class="trail__fav" role="button">
# <div :class="false ? 'icon-save-to-list--saved' : 'icon-save-to-list--empty'" class="trail__savetolist-img icon-save-to-list" ref="fav-icon-28086989">
# </div>
# <span class="trail__savetolist-text">
# 													Save to a List</span>
# </small>
# <div class="trail__activity">
# <img alt="Activity" aria-hidden="true" class="trail__activity__icon" height="25" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg"/>
# <span>Hiking</span>
# </div>
# </div>
# </div>
# <div class="trail__near">near Ausserholligen, Canton du Valais (Switzerland)</div>
# <div class="trail__detail">
# <div aria-label="Author" class="trail__detail__author">
# <a href="https://www.wikiloc.com/wikiloc/user.do?id=3016011" title="TheLonely_Walker">
# <img alt="Author" class="trail__detail__author__img" height="45" loading="lazy" src="https://s0.wklcdn.com/image_100/3016011/photo_tn.jpg?1535383100552" width="45"/>
# </a>
# <div class="flex--vertical">
# <a class="trail__detail__author__name" href="https://www.wikiloc.com/wikiloc/user.do?id=3016011">
# 														TheLonely_Walker</a>
# </div>
# </div>
# <dl class="trail__detail__stats">
# <div>
# <dt class="trail__detail__stats__name">Distance</dt>
# <dd class="trail__detail__stats__value">6.58mi</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">Elevation +</dt>
# <dd class="trail__detail__stats__value">2589f</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">TrailRank</dt>
# <dd class="trail__detail__stats__value">
# 													78<span class="trail__rating__separator">|</span>
# <img alt="Rating" class="trail__rating__star" height="18" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/search/star.svg" width="18"/>
# 														5.0</dd>
# </div>
# </dl>
# </div>
# <div class="trail__images trail__images--grid-3">
# <picture @click.stop="goToUrl('/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989/photo-17943042')" class="trail__images--grid-3__0">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.400x300.jpg"/>
# <img alt="Photo of Tour de Grand Dixence, Valais, SUISSE" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.700x525.jpg" srcset="https://s0.wklcdn.com/image_100/3016011/28086990/17943042.400x300.jpg 400w, https://s0.wklcdn.com/image_100/3016011/28086990/17943042.700x525.jpg 700w" width="700">
# </img></picture>
# <picture @click.stop="goToUrl('/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989/photo-17943051')" class="trail__images--grid-3__1">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_100/3016011/28086991/17943051.400x300.jpg"/>
# <img alt="Photo of Tour de Grand Dixence, Valais, SUISSE" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_100/3016011/28086991/17943051.700x525.jpg" srcset="https://s0.wklcdn.com/image_100/3016011/28086991/17943051.400x300.jpg 400w, https://s0.wklcdn.com/image_100/3016011/28086991/17943051.700x525.jpg 700w" width="700"/>
# </picture>
# <picture @click.stop="goToUrl('/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989/photo-17943062')" class="trail__images--grid-3__2">
# <source media="(max-width: 600px)" srcset="https://s2.wklcdn.com/image_100/3016011/28086992/17943062.400x300.jpg"/>
# <img alt="Photo of Tour de Grand Dixence, Valais, SUISSE" class="img-responsive" height="525" loading="lazy" src="https://s2.wklcdn.com/image_100/3016011/28086992/17943062.700x525.jpg" srcset="https://s2.wklcdn.com/image_100/3016011/28086992/17943062.400x300.jpg 400w, https://s2.wklcdn.com/image_100/3016011/28086992/17943062.700x525.jpg 700w" width="700"/>
# </picture>
# </div>
# <p class="trail__description">
# 												This trail starts from the parking at the base of the dam (2130m) and goes all the way up to Col de Roux (2804m).
# Then it goes down and behind the Mont Blava and continues on the left side of the Torrent de Chenna. This...</p>
# <div class="trail__review__container">
# <figure class="trail__review trail__review__0">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Bonito sendero y fotografía.
# Muchas gracias por compartirlo</q>
# <figcaption class="trail__review__author">Pablo de Gárate</figcaption>
# </figure>
# </div>
# <a class="trail__viewtrail" href="/hiking-trails/tour-de-grand-dixence-valais-suisse-28086989">
# 										View trail<img alt="View trail" aria-hidden="true" class="trail__viewtrail__arrow" height="14" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/arrow-right-with-line.svg" width="16"/>
# </a>
# </article>
# </li><li class="trail-list__item">
# <article @click="goToUrl('/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236')" class="trail">
# <div class="trail__header">
# <h2 class="trail__title">
# <a href="/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236" title="Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt trail - Ried, Canton du Valais (Switzerland)">
# 												Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt</a>
# </h2>
# <div class="trail__subtitle">
# <small @click.stop="saveTrailToList(39699236)" class="trail__fav" role="button">
# <div :class="false ? 'icon-save-to-list--saved' : 'icon-save-to-list--empty'" class="trail__savetolist-img icon-save-to-list" ref="fav-icon-39699236">
# </div>
# <span class="trail__savetolist-text">
# 													Save to a List</span>
# </small>
# <div class="trail__activity">
# <img alt="Activity" aria-hidden="true" class="trail__activity__icon" height="25" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg"/>
# <span>Hiking</span>
# </div>
# </div>
# </div>
# <div class="trail__near">near Ried, Canton du Valais (Switzerland)</div>
# <div class="trail__detail">
# <div aria-label="Author" class="trail__detail__author">
# <a href="https://www.wikiloc.com/wikiloc/user.do?id=2701283" title="Ioannis Mountaneas">
# <img alt="Author" class="trail__detail__author__img" height="45" loading="lazy" src="https://s2.wklcdn.com/image_90/2701283/photo_tn.jpg?1550003428790" width="45"/>
# </a>
# <div class="flex--vertical">
# <a class="trail__detail__author__name" href="https://www.wikiloc.com/wikiloc/user.do?id=2701283">
# 														Ioannis Mountaneas</a>
# <div class="trail__detail__author__companions">
# <small class="trail__detail__author__companions__with">with</small>
# <a href="/wikiloc/user.do?id=4121938" style="z-index: 1" title="Stella Frabaschali">
# <img alt="Stella Frabaschali" height="28" loading="lazy" src="https://s1.wklcdn.com/image_137/4121938/photo_tn.jpg?1531319108425" width="28"/>
# </a>
# </div>
# </div>
# </div>
# <dl class="trail__detail__stats">
# <div>
# <dt class="trail__detail__stats__name">Distance</dt>
# <dd class="trail__detail__stats__value">10.71mi</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">Elevation +</dt>
# <dd class="trail__detail__stats__value">3757f</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">TrailRank</dt>
# <dd class="trail__detail__stats__value">
# 													78<span class="trail__rating__separator">|</span>
# <img alt="Rating" class="trail__rating__star" height="18" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/search/star.svg" width="18"/>
# 														5.0</dd>
# </div>
# </dl>
# </div>
# <div class="trail__images trail__images--grid-3">
# <picture @click.stop="goToUrl('/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236/photo-25744100')" class="trail__images--grid-3__0">
# <source media="(max-width: 600px)" srcset="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.400x300.jpg"/>
# <img alt="Photo of Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt" class="img-responsive" height="525" loading="lazy" src="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.700x525.jpg" srcset="https://s2.wklcdn.com/image_90/2701283/39699236/25744100.400x300.jpg 400w, https://s2.wklcdn.com/image_90/2701283/39699236/25744100.700x525.jpg 700w" width="700">
# </img></picture>
# <picture @click.stop="goToUrl('/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236/photo-25744102')" class="trail__images--grid-3__1">
# <source media="(max-width: 600px)" srcset="https://s1.wklcdn.com/image_90/2701283/39699236/25744102.400x300.jpg"/>
# <img alt="Photo of Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt" class="img-responsive" height="525" loading="lazy" src="https://s1.wklcdn.com/image_90/2701283/39699236/25744102.700x525.jpg" srcset="https://s1.wklcdn.com/image_90/2701283/39699236/25744102.400x300.jpg 400w, https://s1.wklcdn.com/image_90/2701283/39699236/25744102.700x525.jpg 700w" width="700"/>
# </picture>
# <picture @click.stop="goToUrl('/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236/photo-25744104')" class="trail__images--grid-3__2">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_90/2701283/39699236/25744104.400x300.jpg"/>
# <img alt="Photo of Zermatt 05/08/2019 Sunnegga - Blauherd - Furggji - Oberrothorn - Stellisee - Grindjisee - Zermatt" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_90/2701283/39699236/25744104.700x525.jpg" srcset="https://s0.wklcdn.com/image_90/2701283/39699236/25744104.400x300.jpg 400w, https://s0.wklcdn.com/image_90/2701283/39699236/25744104.700x525.jpg 700w" width="700"/>
# </picture>
# </div>
# <p class="trail__description">
# 												Ascent to Oberrothorn from Sunnegga and return to Zermatt through lakes Stelisse and Grindjisee. Oberrothorn is claimed as the highest peak in Switzerland (3414m) that can be reached through a hike trail and in summertim...</p>
# <div class="trail__review__container">
# <figure class="trail__review trail__review__0">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Moderate difficulty ascent with very nice scenery</q>
# <figcaption class="trail__review__author">Stella Frabaschali</figcaption>
# </figure>
# </div>
# <a class="trail__viewtrail" href="/hiking-trails/zermatt-05-08-2019-sunnegga-blauherd-furggji-oberrothorn-stellisee-grindjisee-zermatt-39699236">
# 										View trail<img alt="View trail" aria-hidden="true" class="trail__viewtrail__arrow" height="14" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/arrow-right-with-line.svg" width="16"/>
# </a>
# </article>
# </li><li class="trail-list__item">
# <article @click="goToUrl('/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328')" class="trail">
# <div class="trail__header">
# <h2 class="trail__title">
# <a href="/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328" title="Les Diablerets - Creux de Champ - Vers Champ trail - Les Diablerets, Canton de Vaud (Swiss Confederation)">
# 												Les Diablerets - Creux de Champ - Vers Champ</a>
# </h2>
# <div class="trail__subtitle">
# <small @click.stop="saveTrailToList(4625328)" class="trail__fav" role="button">
# <div :class="false ? 'icon-save-to-list--saved' : 'icon-save-to-list--empty'" class="trail__savetolist-img icon-save-to-list" ref="fav-icon-4625328">
# </div>
# <span class="trail__savetolist-text">
# 													Save to a List</span>
# </small>
# <div class="trail__activity">
# <img alt="Activity" aria-hidden="true" class="trail__activity__icon" height="25" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg"/>
# <span>Hiking</span>
# </div>
# </div>
# </div>
# <div class="trail__near">near Les Diablerets, Canton de Vaud (Swiss Confederation)</div>
# <div class="trail__detail">
# <div aria-label="Author" class="trail__detail__author">
# <a href="https://www.wikiloc.com/wikiloc/user.do?id=91667" title="Koolloos">
# <img alt="Author" class="trail__detail__author__img" height="45" loading="lazy" src="https://s2.wklcdn.com/image_3/91667/photo_tn.jpg?1495786997294" width="45"/>
# </a>
# <div class="flex--vertical">
# <a class="trail__detail__author__name" href="https://www.wikiloc.com/wikiloc/user.do?id=91667">
# 														Koolloos</a>
# </div>
# </div>
# <dl class="trail__detail__stats">
# <div>
# <dt class="trail__detail__stats__name">Distance</dt>
# <dd class="trail__detail__stats__value">6.29mi</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">Elevation +</dt>
# <dd class="trail__detail__stats__value">1749f</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">TrailRank</dt>
# <dd class="trail__detail__stats__value">
# 													77<span class="trail__rating__separator">|</span>
# <img alt="Rating" class="trail__rating__star" height="18" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/search/star.svg" width="18"/>
# 														5.0</dd>
# </div>
# </dl>
# </div>
# <div class="trail__images trail__images--grid-3">
# <picture @click.stop="goToUrl('/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328/photo-2330005')" class="trail__images--grid-3__0">
# <source media="(max-width: 600px)" srcset="https://s1.wklcdn.com/image_3/91667/4625328/2330005.400x300.jpg"/>
# <img alt="Photo of Les Diablerets - Creux de Champ - Vers Champ" class="img-responsive" height="525" loading="lazy" src="https://s1.wklcdn.com/image_3/91667/4625328/2330005.700x525.jpg" srcset="https://s1.wklcdn.com/image_3/91667/4625328/2330005.400x300.jpg 400w, https://s1.wklcdn.com/image_3/91667/4625328/2330005.700x525.jpg 700w" width="700">
# </img></picture>
# <picture @click.stop="goToUrl('/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328/photo-2330006')" class="trail__images--grid-3__1">
# <source media="(max-width: 600px)" srcset="https://s2.wklcdn.com/image_3/91667/4625328/2330006.400x300.jpg"/>
# <img alt="Photo of Les Diablerets - Creux de Champ - Vers Champ" class="img-responsive" height="525" loading="lazy" src="https://s2.wklcdn.com/image_3/91667/4625328/2330006.700x525.jpg" srcset="https://s2.wklcdn.com/image_3/91667/4625328/2330006.400x300.jpg 400w, https://s2.wklcdn.com/image_3/91667/4625328/2330006.700x525.jpg 700w" width="700"/>
# </picture>
# <picture @click.stop="goToUrl('/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328/photo-2330007')" class="trail__images--grid-3__2">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_3/91667/4625328/2330007.400x300.jpg"/>
# <img alt="Photo of Les Diablerets - Creux de Champ - Vers Champ" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_3/91667/4625328/2330007.700x525.jpg" srcset="https://s0.wklcdn.com/image_3/91667/4625328/2330007.400x300.jpg 400w, https://s0.wklcdn.com/image_3/91667/4625328/2330007.700x525.jpg 700w" width="700"/>
# </picture>
# </div>
# <p class="trail__description">
# 												Si te gusta esta ruta y/o la has seguido, me gustaría conocer tú valoración y comentarios. Muchas gracias.
# If you like this route and/or you followed it, please leave a valoration and/or comment. Thanx!
#
# Circular walk...</p>
# <div class="trail__review__container">
# <figure class="trail__review trail__review__0">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Hi dear friend
# You have followed and recorded many beautiful and exciting paths
# Please also visit my page and comment ...</q>
# <figcaption class="trail__review__author">mehdi.tabibvand</figcaption>
# </figure>
# <figure class="trail__review trail__review__1">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Nice pretty and peaceful</q>
# <figcaption class="trail__review__author">laurene.descouts</figcaption>
# </figure>
# <figure class="trail__review trail__review__2">
# <span class="trail__review__rating rating star5"></span>
# <q class="trail__review__text">Una ruta koolloos con muy buena pinta que habrá repetir en cuanto vuelva a tierras galas.
# Saludos</q>
# <figcaption class="trail__review__author">sextante</figcaption>
# </figure>
# </div>
# <a class="trail__viewtrail" href="/hiking-trails/les-diablerets-creux-de-champ-vers-champ-4625328">
# 										View trail<img alt="View trail" aria-hidden="true" class="trail__viewtrail__arrow" height="14" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/arrow-right-with-line.svg" width="16"/>
# </a>
# </article>
# </li><li class="trail-list__ad">
# <!-- Trail Card -->
# <section aria-label="Ad" class="adpremium adpremium--landscape" onclick="gtag('event', 'weather', {'event_category': 'adpremium_native', 'event_label': location.href, 'transport_type': 'beacon'}); location.href='/premium?ref=adpremium_native-weather'">
# <div class="adpremium__body">
# <svg aria-hidden="true" height="0" width="0">
# <defs>
# <clippath clippathunits="objectBoundingBox" id="maskPortrait">
# <path d="M0.02,0 C0.01,0,0.002,0.007,0.002,0.016 V1 C0.134,0.994,0.23,0.981,0.323,0.969 C0.489,0.946,0.649,0.925,1,0.944 V0.016 C1,0.007,0.994,0,0.984,0 H0.02"></path>
# </clippath>
# </defs>
# </svg>
# <svg aria-hidden="true" height="0" width="0">
# <defs>
# <clippath clippathunits="objectBoundingBox" id="maskLandscape">
# <path d="M0.001,0.026 C0.001,0.013,0.006,0.002,0.013,0.002 C0.132,0.002,1,0.002,0.994,0.002 C0.884,0.002,0.898,1,0.748,1 C0.611,1,0.097,1,0.013,1 C0.006,1,0.001,0.991,0.001,0.978 V0.026"></path>
# </clippath>
# </defs>
# </svg>
# <h3>Weather Forecast</h3>
# <p aria-label="Feature Description">A great hint to help you choose your outdoor gear and clothing!</p>
# <a class="wlbutton wlbutton--pri-orange" href="/premium?ref=adpremium_native-weather" onclick="gtag('event', 'weather', {'event_category': 'adpremium_native', 'event_label': location.href, 'transport_type': 'beacon'})">Get Wikiloc Premium</a>
# <small>Upgrade to remove Ads</small>
# </div>
# <img alt="Weather Forecast" class="adpremium__img adpremium__img-mobile" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/adpremium/weather_mobile.png"/>
# <img alt="Weather Forecast" class="adpremium__img adpremium__img-landscape adpremium__img-landscapeformat" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/adpremium/weather_desktop.png"/>
# </section>
# </li>
# <li class="trail-list__item">
# <article @click="goToUrl('/hiking-trails/rigi-staffel-from-seebodenalp-60683108')" class="trail">
# <div class="trail__header">
# <h2 class="trail__title">
# <a href="/hiking-trails/rigi-staffel-from-seebodenalp-60683108" title="Rigi Staffel from Seebodenalp trail - Rigi Staffel, Kanton Schwyz (Switzerland)">
# 												Rigi Staffel from Seebodenalp</a>
# </h2>
# <div class="trail__subtitle">
# <small @click.stop="saveTrailToList(60683108)" class="trail__fav" role="button">
# <div :class="false ? 'icon-save-to-list--saved' : 'icon-save-to-list--empty'" class="trail__savetolist-img icon-save-to-list" ref="fav-icon-60683108">
# </div>
# <span class="trail__savetolist-text">
# 													Save to a List</span>
# </small>
# <div class="trail__activity">
# <img alt="Activity" aria-hidden="true" class="trail__activity__icon" height="25" src="https://sc.wklcdn.com/wikiloc/images/pictograms/svg-wm/1.svg">
# <span>Hiking</span>
# </img></div>
# </div>
# </div>
# <div class="trail__near">near Rigi Staffel, Kanton Schwyz (Switzerland)</div>
# <div class="trail__detail">
# <div aria-label="Author" class="trail__detail__author">
# <a href="https://www.wikiloc.com/wikiloc/user.do?id=2604514" title="goartandkitchen">
# <img alt="Author" class="trail__detail__author__img" height="45" loading="lazy" src="https://s1.wklcdn.com/image_86/2604514/photo_tn.jpg?1485116042373?344" width="45">
# </img></a>
# <div class="flex--vertical">
# <a class="trail__detail__author__name" href="https://www.wikiloc.com/wikiloc/user.do?id=2604514">
# 														goartandkitchen</a>
# </div>
# </div>
# <dl class="trail__detail__stats">
# <div>
# <dt class="trail__detail__stats__name">Distance</dt>
# <dd class="trail__detail__stats__value">8.87mi</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">Elevation +</dt>
# <dd class="trail__detail__stats__value">2359f</dd>
# </div>
# <div>
# <dt class="trail__detail__stats__name">TrailRank</dt>
# <dd class="trail__detail__stats__value">
# 													77<span class="trail__rating__separator">|</span>
# <img alt="Rating" class="trail__rating__star" height="18" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/search/star.svg" width="18"/>
# 														5.0</dd>
# </div>
# </dl>
# </div>
# <div class="trail__images trail__images--grid-3">
# <picture @click.stop="goToUrl('/hiking-trails/rigi-staffel-from-seebodenalp-60683108/photo-40440468')" class="trail__images--grid-3__0">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_86/2604514/60683108/40440468.400x300.jpg"/>
# <img alt="Photo of Rigi Staffel from Seebodenalp" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_86/2604514/60683108/40440468.700x525.jpg" srcset="https://s0.wklcdn.com/image_86/2604514/60683108/40440468.400x300.jpg 400w, https://s0.wklcdn.com/image_86/2604514/60683108/40440468.700x525.jpg 700w" width="700">
# </img></picture>
# <picture @click.stop="goToUrl('/hiking-trails/rigi-staffel-from-seebodenalp-60683108/photo-40440471')" class="trail__images--grid-3__1">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_86/2604514/60683109/40440471.400x300.jpg"/>
# <img alt="Photo of Rigi Staffel from Seebodenalp" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_86/2604514/60683109/40440471.700x525.jpg" srcset="https://s0.wklcdn.com/image_86/2604514/60683109/40440471.400x300.jpg 400w, https://s0.wklcdn.com/image_86/2604514/60683109/40440471.700x525.jpg 700w" width="700"/>
# </picture>
# <picture @click.stop="goToUrl('/hiking-trails/rigi-staffel-from-seebodenalp-60683108/photo-40440477')" class="trail__images--grid-3__2">
# <source media="(max-width: 600px)" srcset="https://s0.wklcdn.com/image_86/2604514/60683110/40440477.400x300.jpg"/>
# <img alt="Photo of Rigi Staffel from Seebodenalp" class="img-responsive" height="525" loading="lazy" src="https://s0.wklcdn.com/image_86/2604514/60683110/40440477.700x525.jpg" srcset="https://s0.wklcdn.com/image_86/2604514/60683110/40440477.400x300.jpg 400w, https://s0.wklcdn.com/image_86/2604514/60683110/40440477.700x525.jpg 700w" width="700"/>
# </picture>
# </div>
# <p class="trail__description">
# 												Tris Loop trail from Seebodenalp - Rigi Staffel an back is a moderately hard trail located near Küssnacht am Rigi, Schwyz, Switzerland.
# The starting point can be reached by car or with the cable car form Küssnacht.
# The...</p>
# <div class="trail__review__container">
# <figure class="trail__review trail__review__0">
# ...
# <a href="https://www.wikiloc.com/trails/mountain-biking/switzerland">
# 										Mountain Bike trails in Switzerland</a>
# </li>
# <li class="sidebar__links__discover">
# <a href="https://www.wikiloc.com/trails/outdoor/switzerland">
# 									Discover other outdoor activities in this region</a>
# </li>
# </ul>
# </div> </div></main>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/underscore.js/1.8.3/underscore-min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.2/js/bootstrap.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-cookie/1.4.0/jquery.cookie.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/vue@2.5.11/dist/vue.min.js"></script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/vue/components/header-user.min.4c50d0f3.js"></script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/vue/components/language-selector.min.1614f93e.js"></script>
# <script>
#   Vue.prototype.$eventBus = new Vue();
# </script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/common.min.2d3102f3.js?v=1.3.3"></script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/vue/components/search-box.min.97ab9cd1.js"></script>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/vue/components/explore.min.cf62805e.js"></script>
# <script>var isoLang = 'en';</script>
# <script>
#   var countryCode = "NL";
#   var cookieWikilocConsent = "wikiloc_cookie_consent";
#   var translationsCookiesJs = {"txtCookieMonsterPopupCookie2Title":"Those of measurement and analysis, to be more professional","txtCookieMonsterConfiguration":"Manage Cookies","txtCookieMonsterAcceptCookies":"Accept Cookies","txtCookieMonsterPopupCookie1Text":"These cookies allow for the proper functioning of our website, such as browsing through the website, accessing your personal account or the use of security elements while browsing. They are necessary as they allow for communication between your device and the network, or because they provide a service specifically requested by you.","txtCookieMonsterBannerTitle":"Select your cookie preferences","txtCookieMonsterPopupTitle":"Cookie Settings","txtCookieMonsterPopupCookie1Title":"The technical and necessary ones. The ones you can't do without.","txtCookieMonsterPopupCookie2Text":"These are those cookies that allow us to quantify the number of users that enter our page and analyze the use that is made of it. The aim is precisely to constantly improve and to enhance your experience.","txtCookieMonsterPopupCookie3Title":"Those of marketing and segmented advertising","txtCookieMonsterPopupCookie3Text":"These are the types of cookies that make the management of the advertising spaces on our website possible. These cookies store information about user behavior. Although it sounds like control, it is done precisely to prevent spam from reaching you and to show you the content that we know is of greater interest for you.","txtCookieMonsterBannerText":"At Wikiloc, we use our own cookies as well as third-party cookies, just like on most websites. In our case, we use them for technical, analytical and advertising purposes only. You can choose your preferences in \"Manage Cookies\". For more information, you can visit the Cookies section of our <a href=\"\/wikiloc\/privacy.html?v4.0#cookies\" class=\"wikiloc-link\">Privacy Policy<\/a>."};
# </script>
# <div id="vue-cookie-monster"></div>
# <link href="https://sc.wklcdn.com/wikiloc/assets/styles/css/vue/components/sid-monster.min.d57d086a.css" rel="stylesheet"/>
# <script src="https://sc.wklcdn.com/wikiloc/assets/scripts/vue/components/sid-monster.min.8c42f191.js"></script>
# <script>
#   function initCookieMonster() {
#     var elementId = "vue-cookie-monster";
#     if(!document.getElementById(elementId)) {
#       return;
#     }
#
#     new Vue({
#       el: '#'+elementId,
#       data: {
#         countryCode: countryCode,
#         cookieWikilocConsent: cookieWikilocConsent,
#         i18n: translationsCookiesJs
#       },
#       template: `
# 			 <cookie-monster
# 			  :countryCode="countryCode"
# 			  :cookieName="cookieWikilocConsent"
# 			  :i18n="i18n">
#
# 			</cookie-monster>
# 			`
#     });
#   }
#   setTimeout(initCookieMonster, 200);
# </script><script src="https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js"></script>
# <script>
# 	function onDomReady(fn) {
# 	  // If we're early to the party
# 	  document.addEventListener("DOMContentLoaded", fn);
# 	  // If late; I mean on time.
# 	  if (
# 		document.readyState === "interactive" ||
# 		document.readyState === "complete"
# 	  ) {
# 		fn();
# 	  }
# 	}
#
# 	var languageCode = 'en';
# 	var translations = {"txtShowAll":"Show all","txtViewLess":"View less","txtViewAll":"View all","txtNameList":"Name","txtFeatureName":"Advanced Filters","txtFeatureNameFavourite":"Trail Lists","txtFeatureDescription":"<p>Find trails only from people you are following.<\/p><p>Filter by recording date (last month, quarter, year).<\/p><p>Filter by recording month: mark one month or more to find trails recorded in a specific season.<\/p>","txtView":"View","txtModalPremiumLogin":"Already a member? Log in","txtFollowModalPhotoOf":"Photo of","txtNewList":"New List","txtTrailsLabel":"trails","txtReachedLimit":"You have reached the maximum number of lists","txtNotNow":"NOT NOW","txtViewList":"View all","txtRemainingList":"???en.view-action.favorite-list.remaining-list???","txtPlaceholderList":"Enter List name","txtWikilocPremium":"Upgrade to Premium","txtFollowModalTitle":"Trail added to your favorites","txtRemaining":"remaining","txtPrivacy":"Privacy","txtFeatureDescriptionFavourite":"<p>Organize the trails you like in lists and share them with your friends.<\/p><p>Create your own lists to save your favorite trails, set goals or even plan future trips!<\/p>","txtPremiumFeature":"PREMIUM FEATURE","txtPrivate":"Private","txtPrivacyHelp":"Private lists are visible to you alone and cannot be shared","txtFollowModalFollowButton":"Follow","txtFollowModalDiscover":"Follow {0} and discover new trails!","txtCreateList":"Create","txtAddToList":"Save to a List","txtTrial":"Get a FREE 14-day trial","txtPublic":"Public","txtPromotedTrails":"Promoted trails"};
#     var language = "en";
#
#     var userType = "USER_ANONYMOUS";
#
# 	onDomReady(() => {
# 	  document
# 		.querySelector(".description__read-more")
# 		?.addEventListener("click", function (event) {
# 		  event.target.style.display = "none";
# 		  document.querySelector(".description2").style.display = "initial";
# 		  event.preventDefault();
# 		});
#
# 	  new Vue({
# 		el: "#v-trail-list",
# 		data: {
# 		  i18n: translations,
# 		  isFavModalOpen: {},
# 		  isUserPremium: userType === "USER_PREMIUM",
# 		},
# 		methods: {
# 		  saveTrailToList: function (trailId) {
# 			if (userType === "USER_ANONYMOUS") {
# 			  location.href = "/wikiloc/start.do?NEXTHOP=aHR0cHM6Ly93d3cud2lraWxvYy5jb20vdHJhaWxzL2hpa2luZy9zd2l0emVybGFuZA==";
# 			} else {
# 			  this.$set(this.isFavModalOpen, trailId, true);
# 			}
# 		  },
# 		  goToUrl: function (href) {
# 			location.href = href;
# 		  },
# 		  syncIsFavorite: function (payload) {
# 			if (payload.isFavorite) {
# 			  this.$refs["fav-icon-" + payload.trailId].classList.add(
# 				"icon-save-to-list--saved"
# 			  );
# 			  this.$refs["fav-icon-" + payload.trailId].classList.remove(
# 				"icon-save-to-list--empty"
# 			  );
# 			} else {
# 			  this.$refs["fav-icon-" + payload.trailId].classList.add(
# 				"icon-save-to-list--empty"
# 			  );
# 			  this.$refs["fav-icon-" + payload.trailId].classList.remove(
# 				"icon-save-to-list--saved"
# 			  );
# 			}
# 		  },
# 		  syncIsModalOpen: function (payload) {
# 			this.$set(this.isFavModalOpen, parseInt(payload.trailId, 10), false);
# 		  },
# 		},
# 	  });
# 	});
#
# 	</script>
# <footer id="footer-main">
# <div class="container" id="footer-nav">
# <div class="row">
# <div class="col-sm-2 col-xs-12">
# <h2>Get the App</h2>
# <div class="col-sm-12 col-xs-6 remove-padding-left">
# <a href="https://apps.apple.com/us/app/wikiloc-outdoor-navigation-gps/id432102730?pt=502712&amp;ct=wikiloc_banner_footer&amp;mt=8">
# <img alt="Available on the iPhone App Store" class="img-responsive" height="40" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/apple-store.png" width="135">
# </img></a>
# </div>
# <div class="col-sm-12 col-xs-6 remove-padding-left">
# <a href="https://play.google.com/store/apps/details?id=com.wikiloc.wikilocandroid&amp;hl=en&amp;referrer=utm_source%3Dfooter%26utm_medium%3Dweb%26utm_campaign%3Dwikiloc_app_banner">
# <img alt="Get it on Google Play" class="img-responsive" height="40" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/google-play-badge-en.png" width="135">
# </img></a>
# </div>
# </div>
# <div class="col-sm-9">
# <div class="col-sm-6 col-xs-12">
# <h2>Explore Trails</h2>
# <div class="row">
# <div class="col-xs-6 col-md-6 col-sm-6">
# <ul>
# <li><a href="https://www.wikiloc.com/wikiloc/map.do" rel="nofollow">World Map</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/map.do?sw=-80.41570744462179%2C-202.85156250000003&amp;ne=80.53207112232734%2C202.1484375&amp;viewMode=1" rel="nofollow">Explore by Photos</a></li>
# <li><a href="https://www.wikiloc.com/trails">All Activities &amp; Countries</a></li>
# <li><a href="https://www.wikiloc.com/planet/">Wikiloc Planet</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-md-6 col-sm-6">
# <ul>
# <li><a href="https://www.wikiloc.com/trails/hiking ">Hiking</a></li>
# <li><a href="https://www.wikiloc.com/trails/mountain-biking ">Mountain Bike</a></li>
# <li><a href="https://www.wikiloc.com/trails/cycling ">Road Bike</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/orgs.do">Official Trails</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-sm-3 col-xs-6">
# <h2>About Wikiloc</h2>
# <ul>
# <li><a href="https://www.wikiloc.com/wikiloc/about-us.do">About us</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/findPeople.do">Community Members</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/donate.do?event=donors">Donors</a></li>
# <li><a href="https://help.wikiloc.com">Help Center</a></li>
# <li><a href="https://www.wikiloc.com/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <h2>Services</h2>
# <ul>
# <li><a href="https://www.wikiloc.com/premium?ref=footer">Wikiloc Premium</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/pois.do">Promote your business</a></li>
# <li><a href="https://www.wikiloc.com/wikiloc/org.do">Promote your trails</a></li>
# </ul>
# </div>
# </div>
# <div class="col-sm-1 col-xs-6">
# <a href="/wikiloc/one-percent.do" onclick="gtag('event', 'click', {event_category: 'link', event_label: 'open-one-percent-landing', transport_type: 'beacon'});" style="text-decoration:none; padding-top: 13px;">
# <img alt="Logo 1% for the Planet" class="img-responsive" height="676" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/onepercent/onepercent-logo-vertical-white.png" style="width: 100px" title="Logo 1% for the Planet" width="526">
# </img></a>
# </div>
# </div>
# </div>
# <div class="container-grey">
# <div class="container" id="footer-copyright">
# <div id="footer-copyright-ornament"></div>
# <div class="row reorder-xs">
# <div class="col-xs-12 col-sm-8 col-md-9" id="footer-copyright-text">
# <p>© Wikiloc. All rights reserved. <a href="https://www.wikiloc.com/wikiloc/terms_en.html?v=6.0">Terms of use</a> | <a href="https://www.wikiloc.com/wikiloc/privacy.html?v4.0">Privacy</a> | <a href="https://www.wikiloc.com/wikiloc/privacy.html?v4.0#cookies">Cookie policy</a></p>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-2" id="social-media">
# <div>
# <a href="https://twitter.com/wikiloc" onclick="gtag('event', 'click', {event_category: 'link', event_label: 'redirect-to-twitter-account', transport_type: 'beacon'});">
# <img alt="Twitter icon" class="social-icon social-icon-white pul-right" height="26" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/icons/icon-twitter.png" width="30"/>
# </a>
# <a href="https://instagram.com/wikiloc/" onclick="gtag('event', 'click', {event_category: 'link', event_label: 'redirect-to-instagram-account', transport_type: 'beacon'});">
# <img alt="Instagram icon" class="social-icon social-icon-white pul-right" height="30" loading="lazy" src="https://sc.wklcdn.com/wikiloc/assets/styles/images/icons/icon-instagram.png" width="30"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-1 col-md-1">
# <div class="dropup" id="select-language">
# <a class="dropdown-toggle btn" data-toggle="dropdown" href="#">
# 									English<span class="icon icon-up-open"></span>
# </a>
# <ul class="dropdown-menu dropdown-menu-right" id="lang-selector">
# <li><a href="https://www.wikiloc.com" id="en">English</a></li>
# <li><a href="//ca.wikiloc.com" id="ca">Català</a></li><li><a href="//da.wikiloc.com" id="da">Dansk</a></li><li><a href="//de.wikiloc.com" id="de">Deutsch</a></li><li><a href="//es.wikiloc.com" id="es">Español</a></li><li><a href="//eu.wikiloc.com" id="eu">Euskara</a></li><li><a href="//fr.wikiloc.com" id="fr">Français</a></li><li><a href="//gl.wikiloc.com" id="gl">Galego</a></li><li><a href="//is.wikiloc.com" id="is">Íslenska</a></li><li><a href="//it.wikiloc.com" id="it">Italiano</a></li><li><a href="//hu.wikiloc.com" id="hu">Magyar</a></li><li><a href="//nl.wikiloc.com" id="nl">Nederlands</a></li><li><a href="//nb.wikiloc.com" id="nb">Norsk</a></li><li><a href="//pl.wikiloc.com" id="pl">Polski</a></li><li><a href="//pt.wikiloc.com" id="pt">Português</a></li><li><a href="//fi.wikiloc.com" id="fi">Suomi</a></li><li><a href="//sv.wikiloc.com" id="sv">Svenska</a></li><li><a href="//tr.wikiloc.com" id="tr">Türkçe</a></li><li><a href="//el.wikiloc.com" id="el">Ελληνικά</a></li><li><a href="//ru.wikiloc.com" id="ru">Русский</a></li><li><a href="//sr.wikiloc.com" id="sr">Српски</a></li><li><a href="//uk.wikiloc.com" id="uk">Українська</a></li><li><a href="//zh.wikiloc.com" id="zh">中文</a></li><li><a href="//ko.wikiloc.com" id="ko">한국어</a></li><li class="arrow"></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
# 	var isLangCancelled = false;
#
# 	window.addEventListener('DOMContentLoaded', function (event) {
# 		var switchLangCancel = document.querySelector('#switch_lang_cancel');
# 		if(switchLangCancel) {
# 			switchLangCancel.addEventListener('click', function () {
# 				isLangCancelled = true;
# 			});
# 		}
# 		hasToAddPaddingToBottom();
# 		var accept = document.querySelector('#acept-cookies');
# 		if(accept) {
# 			accept.addEventListener('click', function (event) {
# 				accept.style.display = 'none';
# 				hasToAddPaddingToBottom(event);
# 			});
# 		}
#
# 		var selectLanguage = document.querySelector('#select-language');
# 		if(selectLanguage) {
# 			selectLanguage.addEventListener('click', function () {
# 				var switchLangCancel = document.querySelector('#switch_lang_cancel');
# 				if (switchLangCancel) {
# 					switchLangCancel.click();
# 				}
# 			});
# 		}
# 	});
#
# 	/**
# 	 * Add padding to the bottom of the page if the cookie is displayed
# 	 */
# 	function hasToAddPaddingToBottom(event) {
# 		var cookieMonster = document.querySelector('#cookie-monster');
# 		var footer = document.querySelector('#footer-copyright-text');
# 		if ( (cookieMonster && cookieMonster.style.display === 'block') && !event) {
# 			footer.style.paddingBottom = '50px';
# 		} else {
# 			footer.style.paddingBottom =  '0';
# 		}
# 	}
#
# </script></body>
# </html>

# %%
# from bs4 import BeautifulSoup

# URL = "https://realpython.github.io/fake-jobs/"
# page = requests.get(URL)

# soup = BeautifulSoup(page.content, "html.parser")

# results = soup.find(id="ResultsContainer")

# print(results.prettify())

# %%
# import requests
# from bs4 import BeautifulSoup

# URL = "https://www.wikiloc.com/trails/hiking/switzerland"
# page = requests.get(URL)

# soup = BeautifulSoup(page.content, "html.parser")

# results = soup.find(id="content")

# print(results.prettify())

# %%
# hiking_trails_swiss= []

# for i in range(1,2):
#     response = requests.get(f"https://www.wikiloc.com/trails/hiking/switzerland/")
#     content = response.content
#     parser = BeautifulSoup(content, 'html.parser')
#     body = parser.body
#     trails = body.find_all(id_="trails")
#     hiking_trails_swiss.extend(trails) 
# len(hiking_trails_swiss)

# lijst =[]

# for i in hiking_trails_swiss:
#     title_element = i.find(class_="trail__title").get_text()
#     intro_element = i.find(class_="trail__description").get_text()
#     # print(title_element)
#     # print(intro_element)
#     lijst.append([title_element, intro_element])
#     # print()

# print(lijst[:3])
