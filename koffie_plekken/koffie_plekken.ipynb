# %%
from selenium import webdriver

DRIVER_PATH = '/path/to/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH)
driver.get('https://google.com')
# Out:
# /var/folders/kd/xcgd1prn3b7c2jnsrf4g_qw40000gn/T/ipykernel_31817/4253058543.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=DRIVER_PATH)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")

driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get("https://europeancoffeetrip.com")
print(driver.page_source)

# Find the button and click it
button = driver.find_element_by_id('menu-item-28316')
button.click()

driver.quit()
# Out:
# /var/folders/kd/xcgd1prn3b7c2jnsrf4g_qw40000gn/T/ipykernel_31817/1360160250.py:5: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# /var/folders/kd/xcgd1prn3b7c2jnsrf4g_qw40000gn/T/ipykernel_31817/1360160250.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
# <html lang="en-GB"><head>
# ...

# %%
# import pandas as pd
# import numpy as np
# import requests
# from bs4 import BeautifulSoup

# %%
# coffee_locations = []

# for i in range(1,5):
#     response = requests.get(f"https://europeancoffeetrip.com/uk/")
#     content = response.content
#     parser = BeautifulSoup(content, 'html.parser')
#     body = parser.body
#     locaties = body.find_all(class_="cg-single-item third vertical-center lazyloaded")

# %%
# locations_list =[]

# for coffee_recept in coffee_locations:
#     title_element = coffee_recept.find(class_="entry-title").get_text()
#     intro_element = coffee_recept.find(class_="entry-content").get_text()
#     # print(title_element)
#     # print(intro_element)
#     loc_list.append([title_element, intro_element])
#     # print()

# print(locations_list[:100])

# %%
import requests

url = 'https://europeancoffeetrip.com/uk/'

data = requests.get(url)

print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# ...

# %%
from bs4 import BeautifulSoup

my_data = []

html = BeautifulSoup(data.text, 'html.parser')
locations = html.select('.cg-single-item vertical-center lazyloaded')

for location in locations:

    name = location.select('.cg-list-single-title')[0].get_text()
    city = location.select('.cg-list-single-meta')[0].get_text()
    my_data.append({"title": name, "city": city})

print(my_data)
# Out:
# []
